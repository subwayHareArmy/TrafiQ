# %%
import osmnx as ox
import networkx as nx
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import time
# %matplotlib inline

# %%
place_name = "Beijing, China"

# %% [markdown]
# We now import the dataset here.

# %%
graph = ox.graph_from_place('Beijing, China', which_result=2, network_type='drive')
graph_proj = ox.project_graph(graph)
fig, ax = ox.plot_graph(graph_proj)
# Out:
# C:\Users\C72178\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
beijing_graph = ox.remove_isolated_nodes(graph)
print("We removed of the order of {} number of nodes.".format(len(beijing_graph) - len(graph)) )


beijing_gdf = ox.graph_to_gdfs(beijing_graph, nodes=True, edges=True, node_geometry=True, fill_edge_geometry=True)
# Out:
# We removed of the order of 0 number of nodes.

# %%
# IO handling - Load and Save
folder='C:/Users/C72178/Downloads/T Drive/everything'

ox.save_graphml(beijing_graph, filename='beijing_graph.graphml', folder = folder, gephi=False)

# %%
ox.save_gdf_shapefile(beijing_gdf[0], filename='beijing_gdf_nodes', folder = folder)
ox.save_gdf_shapefile(beijing_gdf[1], filename='beijing_gdf_edges', folder = folder)

# %%
beijing_graph2 = ox.load_graphml(filename='beijing_graph.graphml', folder = folder)

# %%
beijing_graph == beijing_graph2
# Out:
# False

# %%
dataset_path = 'C:/Users/C72178/Downloads/T Drive/release/taxi_log_2008_by_id/'
df = []; df.append([])
inner = 10      #How many times the inner loop is executed
outer = 1       #How many times the outer loop is executed
for _ in range(1,outer+1):
    for __ in range(1,inner+1):
        df.append(pd.read_csv(dataset_path + str(((_-1)*inner)+__) + '.txt', header = None))
len(df)         #The length of df is one more than the number of taxis imported
# Out:
# 11

# %%
#start_time = time.time()
location_points = []; nearest_nodes = []
for _ in range(1,outer+1):
    for __ in range(1,inner+1):
        print("rofl")
        start_time = time.time()
        location_points.append((df[((_-1)*inner)+__][2], df[((_-1)*inner)+__][3]))
        nearest_nodes.append(np.zeros((np.shape(df[((_-1)*inner)+__][2])[0])))
        
        for ___ in range(1, np.shape(df[((_-1)*inner)+__][2])[0] -1):
            nearest_nodes[((_-1)*inner)+__-1][___-1] = ox.get_nearest_node(graph, (location_points[((_-1)*inner)+__-1][0][___-1], location_points[((_-1)*inner)+__-1][1][___-1]), method='haversine', return_dist=False)
            print("lol")
            if time.time() - start_time > 5:
                print("ping"); print(((_-1)*inner)+__,___); start_time = time.time()
# Out:
# rofl
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# ping
# 1 39
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# ping
# 1 78
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# ping
# 1 117
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# ping
# ...

# %%
print(np.shape(location_points))
print(np.shape(nearest_nodes))
print(np.shape(df[((_-1)*inner)+__]))
print(((_-1)*inner)+__)

# %%
nearest_nodes = np.asarray(nearest_nodes)

# %%
start_time = time.time()
for _ in range(1,int(1e3)):
    for __ in range(1,int(1e8)):
        if time.time() - start_time > 5:
                print("ping"); start_time = time.time()
# Out:
# ping
# ping
# ping
# ping
# ping
# ping
# ping
# ping
# ping
# ping
# ping
# ping
# ping
# ping
# ping
# ping
# ping
# ping
# ping
# ping
# ping
# ping
# ping
# ping
# ping
# ping

# %%
9*9

# %%
graph_proj = ox.project_graph(beijing_graph)
graph_proj2 = ox.project_graph(beijing_graph2)
